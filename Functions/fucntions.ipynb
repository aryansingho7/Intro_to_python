# %%
#fucntions
#syntax
#def function_name(parameters):
# """docstrings"
#   statments(s)

#EXAMPLE
# a simple py fucntion to check whether x is even odd

def evenOdd(x):
    if(x%2==0):
        print('even')
    else :
        print('odd')

#drivers code
evenOdd(2)
evenOdd(5)
# Out:
# even
# odd

# %%
#DOCSTRING
#syntax: print(fuction_name._doc_)

#example\
def say_hi():
    'hello geek'

print(say_hi.__doc__)
# Out:
# hello geek

# %%
#example

def square_value(num):
    """this fucntion returns the sauare value of the entered number"""
    return num**2
print(square_value(2))
print(square_value(-4))
# Out:
# 4
# 16

# %%
#pass by reference
# here x is a new reference to same list list
def myFun(x):
    x[1]=20


    #drivers code (note that lst is modifed after being called)
lst=[10,11,12,13,14,15]
myFun(lst)
print(lst)
# Out:
# [10, 20, 12, 13, 14, 15]

# %%
#case of broken referencing where there is no connection between passed and reciving parameters

def myfun(x):
     # After below line link of x with previous
    # object gets broken. A new object is assigned
    # to x.
    x=20

#drivers code 
x=10
myfun(x)
print(x)
# Out:
# 10

# %%
#exercise 
def swap(x,y):
    temp=x
    x=y
    y= temp
#drivers code
x=2
y=3
swap(x, y)
print(x)
print(y)
# Out:
# 2
# 3

# %%
#py program to demonstrate 
# default argument

def myfun(x, y=50):
    print('x:', x)
    print('y:',y)

myfun(10)
# Out:
# x: 10
# y: 30

# %%
#python program to demonstrate keyword argument 
def student(firstname, lastname):
    print(firstname, lastname)

#key arguemnt
student(firstname='aryan', lastname= 'singh')
student(lastname='singh',firstname='aryan')
# Out:
# aryan singh
# aryan singh

# %%
# Python program to illustrate
# *args for variable number of arguments

def myFun(*argv):
    for arg in argv:
        print(arg)
myFun('Hello', 'Welcome', 'to', 'GeeksforGeeks')
# Out:
# Hello
# Welcome
# to
# GeeksforGeeks
