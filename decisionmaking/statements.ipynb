# %%
#python program to illustrate if statement
i=10
if(i>15):
    print('10 is less than 15')
print('i am not if')
# Out:
# i am not if

# %%
#python prograqm to illustrate if else statement

i=20
if(i<15):
    print('I IS SMALLER THAN 15')
    print('im in if block')
else:
    print('i is greater than 15')
    print('im in else block')
print('im not in if or else block')
# Out:
# i is greater than 15
# im in else block
# im not in if or else block

# %%
#python program to illustrate nested if statemnt 
i = 10
if(i==10):
    #first if statment 
    if(i<15):
        print('i is smaller than 15')
        #nested if statement 
    if(i<12):
        print('i is smalle than 12 too')
else:
    print('i is greater than 15')
# Out:
# i is smaller than 15
# i is smalle than 12 too

# %%
#if-elif-else ladder
#python program to illusatrate if-elif-else ladder

i=30
if(i==10):
    print('i is 10')
elif (i==15):
    print('i is 15')
elif(i==20):
    print('i is 20')
else:
    print('i is notpresent')
# Out:
# i is notpresent

# %%
#shorted handed if statemennt
i=10
if i<15: print('i is less than 15')

#short hand if else statment

i=10
print(True) if i<15 else print(False)
# Out:
# i is less than 15
# True
